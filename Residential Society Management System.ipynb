# %%
import mysql.connector
from tkinter import *
from tkinter.ttk import Combobox 
from tkinter import messagebox
from PIL import Image,ImageTk
from tkinter import ttk
import tkinter as tk

root=Tk()
root.title("Login")
root.geometry("1500x1300")
root.configure(bg='skyblue')


my_pic=Image.open('lock.jpg')
resized=my_pic.resize((1500,1300),Image.ANTIALIAS)
new_pic=ImageTk.PhotoImage(resized)
my_label=Label(root,image=new_pic)
my_label.pack(pady=0)

def Ok():
    uname=e1.get()
    password=e2.get()
    
    if(uname == "" and password == ""):
        messagebox.showinfo("","Blank Not Allowed")
        
    elif(uname == "Aditi" and password == "123"):
        
        #messagebox.showinfo("","Login Success")
        root=Tk()
        root.configure(bg='gray')
        root.title('Home Page')
        root.geometry('1500x1300')
        

    
        home=Label(root,text='Welcome To Ekdanta Society',relief='ridge',bd=5,fg='black',bg='skyblue',
        font=('times new roman',19,'bold'),width=50,height=2).place(x=268,y=40)
        regis=Button(root,text='Registration',bg='white',fg='black',relief='ridge',bd=5,font=('times new roman',14),command=show).place(x=160,y=140,width=180,height=50)
        Managers=Button(root,text='Managing Committee',bg='white',fg='black',relief='ridge',bd=5,font=('times new roman',14),command=comm).place(x=440,y=140,width=180,height=50)
        visitor=Button(root,text='Visitors',bg='white',fg='black',relief='ridge',bd=5,font=('times new roman',14),command=Visitor).place(x=160,y=240,width=180,height=50)
        Meeting=Button(root,text='Meeting Arrangement',bg='white',fg='black',relief='ridge',bd=5,font=('times new roman',14),command=meeting).place(x=440,y=240,width=180,height=50)
        Program=Button(root,text='Festivals/Program List',bg='white',fg='black',relief='ridge',bd=5,font=('times new roman',14),command=program).place(x=280,y=320,width=180,height=50)
        show_btn=Button(root,text='Show',bg='white',fg='black',relief='ridge',bd=5,font=('times new roman',15),command=showbtn).place(x=280,y=400,width=180,height=50)
        
        exit_btn=Button(root,text='Exit',bg='#d77337',fg='white',relief='ridge',bd=5,command=root.destroy,font=('times new roman',15,'bold')).place(x=1100,y=550,width=100,height=40)

        root.mainloop()
        
    else:
        messagebox.showinfo("","Incorrect UserName and Password")
#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def show():
    reg=Tk()
    reg.configure(bg='Black')
    reg.title('Home Page')
    reg.geometry('1500x1300')
    
    def add1():
                
        firstname=e_reg.get()
        middlename=e2_reg.get()
        lastname=e3_reg.get()
        gender=Comb.get()
        contact=e4_reg.get()
        city=e5_reg.get()
        address=e6_reg.get()
        member=e7_reg.get()
        flat=e8_reg.get()
        mail=e9_mail.get()
        room=Comb1.get()
    
        if (firstname=='' or middlename=='' or lastname=='' or gender=='' or contact=='' or city=='' or address=='' or member=='' or flat=='' or room=='' or mail==''):
            messagebox.showinfo('Registration','All fields are required to fill')
        else:
            conn=mysql.connector.connect(user='root',password='aditi',host='localhost',database='societymgmt')
            qur='INSERT INTO registration3(firstname,middlename,lastname,gender,contact,city,address,member,flat,room,mail) VALUES("%s","%s","%s","%s","%s","%s","%s","%s","%s","%s","%s")'%(firstname,middlename,lastname,gender,contact,city,address,member,flat,room,mail)
            mycur=conn.cursor()
            mycur.execute(qur)
            conn.commit()
            mycur.close()
            conn.close()
            messagebox.showinfo('Registraion','Information Submitted')
            f1.set('')
            m1.set('')
            l1.set('')
            g1.set('')
            c1.set('')
            ct1.set('')
            ad1.set('')
            mb1.set('')
            flt1.set('')
            room.set('')
            mail1.set('')
            
   
    def delete():
        del_data1=e10.get()
        
        if (del_data1==''):
            messagebox.showinfo('Register Info','All fields are required to fill')
            
        else:
            conn=mysql.connector.connect(user='root',password='aditi',host='localhost',database='societymgmt')
            qur="delete from registration3 where firstname='%s'"%(del_data1)  
            mycur=conn.cursor()
            mycur.execute(qur)
            conn.commit()
            mycur.close()
            conn.close()
            messagebox.showinfo('Register info','Info Deleted')
            ed1.set('')


    f1=StringVar()
    m1=StringVar()
    l1=StringVar()
    g1=StringVar()
    c1=StringVar()
    ct1=StringVar()
    ad1=StringVar()
    mb1=StringVar()
    flt1=StringVar()
    mail1=StringVar()
    r1=StringVar()
    ed1=StringVar()
    

    regl=Label(reg,text='Registration Form',relief='ridge',bd=5,fg='black',bg='orange',
          font=('times new roman',19,'bold'),width=50,height=1).place(x=268,y=20)
   
    fn=Label(reg,text='First Name',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),
             fg='black',bg='white').place(x=50,y=100,width=180,height=40)
    e_reg=Entry(reg,bg='white',textvariable=f1,fg='black',font=('times new roman',15))
    e_reg.place(x=240,y=100,width=200,height=40)

    mn=Label(reg,text='Middle Name',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),
             fg='black',bg='white').place(x=450,y=100,width=180,height=40)
    e2_reg=Entry(reg,bg='white',textvariable=m1,fg='black',font=('times new roman',15))
    e2_reg.place(x=640,y=100,width=200,height=40)

    ln=Label(reg,text='Last Name',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),
             fg='black',bg='white').place(x=850,y=100,width=180,height=40)
    e3_reg=Entry(reg,bg='white',textvariable=l1,fg='black',font=('times new roman',15))
    e3_reg.place(x=1040,y=100,width=200,height=40)
    
    gender=Label(reg,text='Gender',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),
            fg='black',bg='white').place(x=650,y=180,width=180,height=40)
    Comb=Combobox(reg,values=["Male","Female","Other"],textvariable=g1,font=('times new roman',15))
    Comb.place(x=850,y=180,width=200,height=40)

    contact=Label(reg,text='Contact Number',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),
                  fg='black',bg='white').place(x=50,y=260,width=180,height=40)
    e4_reg=Entry(reg,bg='white',fg='black',textvariable=c1,font=('times new roman',15))
    e4_reg.place(x=240,y=260,width=350,height=40)

    city=Label(reg,text='City',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),
               fg='black',bg='white').place(x=50,y=180,width=180,height=40)
    e5_reg=Entry(reg,bg='white',textvariable=ct1,fg='black',font=('times new roman',15))
    e5_reg.place(x=240,y=180,width=200,height=40)

    add=Label(reg,text='Address',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),
              fg='black',bg='white').place(x=50,y=340,width=180,height=40)
    e6_reg=Entry(reg,bg='white',textvariable=ad1,fg='black',font=('times new roman',15))
    e6_reg.place(x=240,y=340,width=350,height=40)

    member=Label(reg,text='Member ID',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),
                 fg='black',bg='white').place(x=50,y=420,width=180,height=40)
    e7_reg=Entry(reg,bg='white',textvariable=mb1,fg='black',font=('times new roman',15))
    e7_reg.place(x=240,y=420,width=350,height=40)

    fltno=Label(reg,text='Flat No',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),
                fg='black',bg='white').place(x=650,y=260,width=180,height=40)
    e8_reg=Entry(reg,bg='white',fg='black',textvariable=flt1,font=('times new roman',15))
    e8_reg.place(x=850,y=260,width=200,height=40)
    
    mail=Label(reg,text="Email ID",relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=650,y=350,width=180,height=40)
    e9_mail=Entry(reg,bg='white',fg='black',font=('times new roman',15),textvariable=mail1)
    e9_mail.place(x=850,y=350,width=300,height=40)

    room=Label(reg,text='Room',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),
               fg='black',bg='white').place(x=50,y=500,width=180,height=40)
    Comb1=Combobox(reg,values=["1 BHK","2 BHK","3 BHK"],textvariable=r1,font=('times new roman',15))
    Comb1.place(x=240,y=500,width=200,height=40)

    
    delete1=Label(reg,text='Delete by Name>>>',relief='ridge',bd=5,fg='black',width=15,bg='white',
          font=('Goudy old style',15,'bold')).place(x=650,y=430)
    e10=Entry(reg,bg='white',fg='black',width=40,bd=5,textvariable=ed1,font=('times new roman',15))
    e10.place(x=850,y=420,width=300,height=40)


    add_btn=Button(reg,text='Add',bg='#d77337',fg='white',relief='ridge',bd=5,font=('times new roman',15),command=add1).place(x=680,y=500,width=180,height=40)
    del_btn=Button(reg,text='Delete',bg='#d77337',fg='white',relief='ridge',bd=5,font=('times new roman',15),command=delete).place(x=680,y=550,width=180,height=40)
    exit_btn=Button(reg,text='Exit',bg='#d77337',fg='white',relief='ridge',bd=5,font=('times new roman',15),command=reg.destroy).place(x=900,y=550,width=180,height=40)

    reg.mainloop()

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def Visitor():
    vis=Tk()
    vis.configure(bg='black')
    vis.title('Home Page')
    vis.geometry('1500x1300')
    
    def add2():
        visitorname=e1_vis.get()
        contactno=e2_vis.get()
        address=e3_vis.get()
        vflatno=e4_vis.get()
        vdate=e5_vis.get()
        vemail=e6_mail.get()
        typ=Comb1.get()
        
    
        if (visitorname=='' or contactno=='' or address=='' or vflatno=='' or vdate=='' or vemail=='' or typ==''):
            messagebox.showinfo('Visitor','All fields are required to fill')
            
        else:
            conn=mysql.connector.connect(user='root',password='aditi',host='localhost',database='societymgmt')
            qur='INSERT INTO visitor(visitorname,contactno,address,vflatno,vdate,vemail,typ) VALUES("%s","%s","%s","%s","%s","%s","%s")'%(visitorname,contactno,address,vflatno,vdate,vemail,typ)
            mycur=conn.cursor()
            mycur.execute(qur)
            conn.commit()
            mycur.close()
            conn.close()
            messagebox.showinfo('Visitor','Information Submitted')
            vn.set('')
            cont.set('')
            add.set('')
            vflt.set('')
            #date.set('')
            email.set('')
            #typ.set('')
            
    def delete1():
        del_data2=e7_del.get()
        
        if (del_data2==''):
            messagebox.showinfo('Visitors Info','All fields are required to fill')
        else:
            conn=mysql.connector.connect(user='root',password='aditi',host='localhost',database='societymgmt')
            qur="delete from visitor where visitorname='%s'"%(del_data2)  
            mycur=conn.cursor()
            mycur.execute(qur)
            conn.commit()
            mycur.close()
            conn.close()
            messagebox.showinfo('Visitors info','Info Deleted')
            e7_del.set()

            
    vn=StringVar()
    cont=StringVar()
    add=StringVar()
    vflt=StringVar()
    date=StringVar()
    email=StringVar()
    type1=StringVar()
    ed2=StringVar()
    
    visl=Label(vis,text='Visitors Information',relief='ridge',bd=5,fg='black',bg='red',
          font=('times new roman',19,'bold'),width=50,height=2).place(x=268,y=20)

    nm=Label(vis,text='Visitor Name',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=50,y=150,width=180,height=40)
    e1_vis=Entry(vis,bg='white',fg='black',textvariable=vn,font=('times new roman',15))
    e1_vis.place(x=260,y=150,width=300,height=40)

    contact=Label(vis,text='Contact Number',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=50,y=250,width=180,height=40)
    e2_vis=Entry(vis,bg='white',fg='black',textvariable=cont,font=('times new roman',15))
    e2_vis.place(x=260,y=250,width=300,height=40)

    addr=Label(vis,text='Address',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=50,y=350,width=180,height=40)
    e3_vis=Entry(vis,bg='white',fg='black',textvariable=add,font=('times new roman',15))
    e3_vis.place(x=260,y=350,width=300,height=40)

    where=Label(vis,text='Visited \n flat no',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=50,y=450,width=180,height=50)
    e4_vis=Entry(vis,bg='white',fg='black',textvariable=vflt,font=('times new roman',15))
    e4_vis.place(x=260,y=450,width=300,height=40)

    date=Label(vis,text='Visited Date',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=680,y=250,width=180,height=50)
    e5_vis=Entry(vis,bg='white',fg='black',textvariable=date,font=('times new roman',15))
    e5_vis.place(x=900,y=250,width=300,height=40)

    mail=Label(vis,text="Email ID",relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=680,y=350,width=180,height=40)
    e6_mail=Entry(vis,bg='white',fg='black',textvariable=email,font=('times new roman',15))
    e6_mail.place(x=900,y=350,width=300,height=40)

    typ=Label(vis,text='Type of Visitor',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=680,y=150,width=180,height=40)
    Comb1=Combobox(vis,values=["Dilivery Boy/Girl","Guest","Employee visitor"],textvariable=type1,font=('times new roman',15))
    Comb1.place(x=900,y=150,width=200,height=40)
    
    delete=Label(vis,text='Delete by Name>>>',relief='ridge',bd=5,fg='black',bg='white',
          font=('Goudy old style',15,'bold')).place(x=680,y=450,width=180,height=40)
    e7_del=Entry(vis,bg='white',fg='black',width=40,bd=5,textvariable=ed2,font=('times new roman',15))
    e7_del.place(x=900,y=450,width=300,height=40)


    add_btn=Button(vis,text='Add',bg='#d77337',fg='white',relief='ridge',bd=5,font=('times new roman',15),command=add2).place(x=400,y=540,width=180,height=40)
    del_btn=Button(vis,text='Delete',bg='#d77337',fg='white',relief='ridge',bd=5,font=('times new roman',15),command=delete1).place(x=600,y=540,width=180,height=40)
    exit_btn=Button(vis,text='Exit',bg='#d77337',fg='white',relief='ridge',bd=5,command=vis.destroy,font=('times new roman',15)).place(x=800,y=540,width=180,height=40)

    vis.mainloop()

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
def comm():
    
    mg=Tk()
    mg.configure(bg='yellow')
    mg.title('Managing Committee')
    mg.geometry='1500x1300'


    mg1=Label(mg,text='Managing Committee',bd=5,fg='black',bg='red',relief='ridge',font=('times new roman',25,'bold'),
          width=40,height=1).place(x=268,y=20)

    mg2=Label(mg,text='Major Segment',bd=5,fg='black',bg='orange',relief='ridge',font=('times new roman',19,'bold'),
          width=15,height=2).place(x=50,y=100)

    mg3=Label(mg,text='Billing & Collection.\n Accounting.\n Property Management.\n Welfare, Staff and Vendor Management and Gate Security Management',
          bd=5,fg='black',bg='skyblue',font=('times new roman',19,'bold'),width=60,height=4).place(x=320,y=100)

    mg4=Label(mg,text='Names of member',bd=5,fg='black',bg='orange',relief='ridge',font=('times new roman',19,'bold'),
          width=15,height=2).place(x=50,y=260)

    mg5=Label(mg,text='Role',bd=5,fg='black',bg='orange',relief='ridge',font=('times new roman',19,'bold'),
          width=15,height=2).place(x=480,y=260)

    mg6=Label(mg,text='Work',bd=5,fg='black',bg='orange',relief='ridge',font=('times new roman',19,'bold'),
          width=15,height=2).place(x=900,y=260)

#name
    mg7=Label(mg,text='Mr. Dilip Hanamghar',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=20,height=1).place(x=50,y=360)
    mg8=Label(mg,text='Mrs. Hanamghar',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=20,height=1).place(x=50,y=420)
    mg9=Label(mg,text='Mr. Gorakshanath Gorad',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=20,height=1).place(x=50,y=480)
    mg10=Label(mg,text='Mr.Dangat',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=20,height=1).place(x=50,y=540)
    mg11=Label(mg,text='Mrs. Sheetal Hanamghar',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=20,height=1).place(x=50,y=600)

# role
    mg12=Label(mg,text='Chairman',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=20,height=1).place(x=480,y=360)
    mg13=Label(mg,text='Secretary',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=20,height=1).place(x=480,y=420)
    mg14=Label(mg,text='Treasurer',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=20,height=1).place(x=480,y=480)
    mg15=Label(mg,text='Society Manager',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=20,height=1).place(x=480,y=540)
    mg16=Label(mg,text='Executive Committee',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=20,height=1).place(x=480,y=600)

# work
    mg17=Label(mg,text='Leader & Head',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=25,height=1).place(x=880,y=360)
    mg18=Label(mg,text='Overall mechanism; Security',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=25,height=1).place(x=880,y=420)
    mg19=Label(mg,text='Finance',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=25,height=1).place(x=880,y=480)
    mg20=Label(mg,text='Daily Executive Functions',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=25,height=1).place(x=880,y=540)
    mg21=Label(mg,text='Day-to-day tasks+welfare programs',bd=5,fg='black',bg='white',font=('times new roman',19,'bold'),
          width=25,height=1).place(x=880,y=600)
    
    exit_btn=Button(mg,text='Exit',bg='#d77337',fg='white',relief='ridge',bd=5,command=mg.destroy,font=('times new roman',15,'bold')).place(x=1160,y=45,width=100,height=40)

    mg.mainloop()

#--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def meeting():
    
    meet=Tk()
    meet.configure(bg='black')
    meet.title('Meeting Arrangement')
    meet.geometry('1500x1300')
    
    def add3():
        agenda=e1_arr.get()
        date=e2_arr.get()
        time=e3_arr.get()
        totalmember=e4_arr.get()
        
        if (agenda=='' or date=='' or time=='' or totalmember==''):
            messagebox.showinfo('Meeting','All fields are required to fill')
        else:
            conn=mysql.connector.connect(user='root',password='aditi',host='localhost',database='societymgmt')
            qur='INSERT INTO meeting(agenda,date,time,totalmember) VALUES("%s","%s","%s","%s")'%(agenda,date,time,totalmember)
            mycur=conn.cursor()
            mycur.execute(qur)
            conn.commit()
            mycur.close()
            conn.close()
            messagebox.showinfo('Visitor','Information Submitted')
            agn.set('')
            #date.set('')
            #time.set('')
            present.set('')
            
    def show1():
        conn=mysql.connector.connect(user='root',password='aditi',host='localhost',database='societymgmt')
        qur='SELECT * FROM meeting'    
        mycur=conn.cursor()
        mycur.execute(qur)
        result=mycur.fetchall()
        for  i in result:
            treev.insert('','end',values=(i[0],i[1],i[2],i[3]))
        conn.commit()
        mycur.close()
        conn.close()
        agn.set('')                                                  # to clear the entries
        #date.set('')
        #time.set('')
        present.set('')
     
            
    
    agn=StringVar()
    date=StringVar()
    time=StringVar()
    present=StringVar()
    
    lb=Label(meet,text='Meeting Arrangement',bg='yellow',fg='black',relief='ridge',font=('times new roman',30,'bold'),
         width=25,height=1).place(x=340,y=20)

    agenda=Label(meet,text='Agenda of Meeting',bg='white',fg='black',relief='ridge',font=('Goudy old style',19,'bold'),
         width=15,height=1).place(x=20,y=120)
    e1_arr=Entry(meet,bg='white',fg='black',textvariable=agn,font=('Goudy old style',19))
    e1_arr.place(x=260,y=120,width=450,height=38)

    date=Label(meet,text='Date of Meeting',bg='white',fg='black',relief='ridge',font=('Goudy old style',19,'bold'),
         width=15,height=1).place(x=20,y=220)
    e2_arr=Entry(meet,bg='white',fg='black',textvariable=date,font=('Goudy old style',19))
    e2_arr.place(x=260,y=220,width=450,height=38)

    time=Label(meet,text='Time of Meeting',bg='white',fg='black',relief='ridge',font=('Goudy old style',19,'bold'),
         width=15,height=1).place(x=20,y=320)
    e3_arr=Entry(meet,bg='white',fg='black',textvariable=time,font=('Goudy old style',19))
    e3_arr.place(x=260,y=320,width=450,height=38)

    total=Label(meet,text='Total Present Member',bg='white',fg='black',relief='ridge',font=('Goudy old style',19,'bold'),
         width=18,height=1).place(x=20,y=420)
    e4_arr=Entry(meet,bg='white',fg='black',textvariable=present,font=('Goudy old style',19))
    e4_arr.place(x=300,y=420,width=100,height=38)

    treev=ttk.Treeview(meet,selectmode='browse',height=20)
    treev.place(x=750,y=140,width=500)
    treev['columns'] = ('1','2','3','4')
    treev['show']='headings'
    treev.column('1',width=90,anchor='c')                 # c = center
    treev.column('2',width=90,anchor='se')                # se= south east
    treev.column('3',width=90,anchor='se')
    treev.column('4',width=90,anchor='se')

    treev.heading('1',text='Agenda of meeting')
    treev.heading('2',text='Date of meeting')
    treev.heading('3',text='Time of meeting')
    treev.heading('4',text='Total Member Present')

    exit_btn=Button(meet,text='EXIT',bg='#d77337',fg='white',relief='ridge',bd=5,command=meet.destroy,font=('times new roman',15)).place(x=150,y=520,width=120,height=50)
    showbt=Button(meet,text='SHOW',relief='ridge',bg='#d77337',fg='white',bd=5,font=('times new roman',15,'bold'),command=show1).place(x=300,y=520,width=120,height=50)
    add_btn=Button(meet,text='ADD',bg='#d77337',fg='white',relief='ridge',bd=5,font=('times new roman',15),command=add3).place(x=450,y=520,width=120,height=50)
    
    meet.mainloop()

#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def program():
    list=Tk()
    list.configure(bg='magenta')
    list.title('Festival & Programs list')
    list.geometry('1500x1300')

    def add():
        n=lentry.get()
        print(n)
        listbox.insert(END,n)
    
    def delete():
        listbox.delete(ANCHOR)

    listbox=Listbox(list,width=25,height=9,font=('times new roman',15,'bold'))
    listbox.place(x=80,y=180)
    #listbox.insert(1,'Republic day')

    L=['Birthday Party','Engagement Ceremony','Republic Day','Makar Sankranti','Holi','Janmashtami','Independence Day','Ganesh Chaturthi','Navratri','Diwali']
    for i in L:
        listbox.insert(END,i)
    
    name=StringVar()    
    lentry=Entry(list,textvariable=name,font=('times new roman',15))
    lentry.place(x=520,y=180,width=400,height=40)
    
    lb=Label(list,text='Festival & Program List',bg='black',fg='yellow',relief='ridge',font=('times new roman',30,'bold'),
         width=25,height=1).place(x=340,y=20)

    tk.Button(list,text='Add Event',relief='ridge',bg='#d77337',fg='white',bd=5,font=('times new roman',15,'bold'),command=add).place(x=660,y=240,width=160,height=50)
    tk.Button(list,text='Delete Event',relief='ridge',bg='#d77337',fg='white',bd=5,font=('times new roman',15,'bold'),command=delete).place(x=660,y=320,width=160,height=50)

    scrollbar=tk.Scrollbar(list,orient='vertical',command=listbox.yview)
    listbox['yscrollcommand']=scrollbar.set
    scrollbar.place(x=320,y=180,width=25,height=220)
    exit_btn=Button(list,text='Exit',bg='#d77337',fg='white',relief='ridge',bd=5,command=list.destroy,font=('times new roman',15,'bold')).place(x=1100,y=550,width=100,height=40)

    
    list.mainloop()
#---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

def showbtn():
    adi=Tk()
    adi.title("Show Login")
    adi.geometry("1500x1300")
    adi.configure(bg='skyblue')
    

    
    def Ok():
        uname=e1.get()
        password=e2.get()
    
        if(uname == "" and password == ""):
            messagebox.showinfo("","Blank Not Allowed")
        
        elif(uname == "Aditi" and password == "Sai"):
            root1=Tk()
            root1.configure(bg='gray')
            root1.title('Home Page')
            root1.geometry('1500x1300')
            
            def regis_details():
                conn=mysql.connector.connect(user='root',password='aditi',host='localhost',database='societymgmt')
                qur='SELECT * FROM registration3'    
                mycur=conn.cursor()
                mycur.execute(qur)
                result=mycur.fetchall()
                for  i in result:
                    treev.insert('','end',values=(i[0],i[1],i[2],i[3],i[4],i[5],i[6],i[7],i[8],i[9],i[10]))
                conn.commit()
                mycur.close()
                conn.close()


            
            treev=ttk.Treeview(root1,selectmode='browse',height=20)
            treev.place(x=80,y=100,width=1100)
            treev['columns'] = ('1','2','3','4','6','7','8','9','10','11')
            treev['show']='headings'
            treev.column('1',width=90,anchor='c')                 # c = center
            treev.column('2',width=90,anchor='se')                # se= south east
            treev.column('3',width=90,anchor='se')
            treev.column('4',width=90,anchor='se')
            treev.column('5',width=90,anchor='se')
            treev.column('6',width=90,anchor='se')
            treev.column('7',width=90,anchor='se')
            treev.column('8',width=90,anchor='se')
            treev.column('9',width=90,anchor='se')
            treev.column('10',width=90,anchor='se')
            treev.column('11',width=90,anchor='se')


            treev.heading('1',text='First Name')
            treev.heading('2',text='Middle Name')
            treev.heading('3',text='Last Name')
            treev.heading('4',text='Gender')
            treev.heading('5',text='Contact Number')
            treev.heading('6',text='City')
            treev.heading('7',text='Address')
            treev.heading('8',text='Member ID')
            treev.heading('9',text='Flat no')
            treev.heading('10',text='Email ID')
            treev.heading('11',text='Room')

        
            regis_details=Button(root1,text='Registration_details',bg='#d77337',fg='black',relief='ridge',bd=5,font=('times new roman',14),command=regis_details).place(x=40,y=40,width=180,height=50)
            next_detail=Button(root1,text='Next',bg='#d77337',fg='black',relief='ridge',bd=5,font=('times new roman',14),command=show).place(x=900,y=540,width=180,height=50)
            exit_btn=Button(root1,text='Exit',bg='#d77337',fg='black',relief='ridge',bd=5,command=root1.destroy,font=('times new roman',14,'bold')).place(x=900,y=600,width=180,height=50)

        else:
             messagebox.showinfo("","Incorrect UserName and Password")  
            
    
    def show(): 
        root2=Tk()
        root2.configure(bg='gray')
        root2.title('Home Page')
        root2.geometry('1500x1300')
        
        def visitor_details():
            conn=mysql.connector.connect(user='root',password='aditi',host='localhost',database='societymgmt')
            qur='SELECT * FROM visitor'    
            mycur=conn.cursor()
            mycur.execute(qur)
            result=mycur.fetchall()
            for  i in result:
                treev.insert('','end',values=(i[0],i[1],i[2],i[3],i[4],i[5],i[6]))
            conn.commit()
            mycur.close()
            conn.close()

         
        treev=ttk.Treeview(root2,selectmode='browse',height=20)
        treev.place(x=80,y=100,width=1100)
        treev['columns'] = ('1','2','3','4','5','6','7')
        treev['show']='headings'
        treev.column('1',width=90,anchor='c')                 # c = center
        treev.column('2',width=90,anchor='se')                # se= south east
        treev.column('3',width=90,anchor='se')
        treev.column('4',width=90,anchor='se')
        treev.column('5',width=90,anchor='se')
        treev.column('6',width=90,anchor='se')
        treev.column('7',width=90,anchor='se')


        treev.heading('1',text='Visitor Name')
        treev.heading('2',text='Contact Number')
        treev.heading('3',text='Address')
        treev.heading('4',text='Visited flat no')
        treev.heading('5',text='Visited Date')
        treev.heading('6',text='Email ID')
        treev.heading('7',text='Type of Visitor')
    
     
        visitors_detail=Button(root2,text='Visitors_details',bg='#d77337',fg='black',relief='ridge',bd=5,font=('times new roman',14),command=visitor_details).place(x=40,y=40,width=180,height=50)
        exit_btn=Button(root2,text='Exit',bg='#d77337',fg='white',relief='ridge',bd=5,command=root2.destroy,font=('times new roman',15,'bold')).place(x=1100,y=550,width=100,height=40)
    
        root2.mainloop()
        

    

    Frame_login=Frame(adi,bg='white')
    Frame_login.place(x=380,y=150,height=340,width=500)

    title=Label(Frame_login,text='Login Here',font=("Impact",35,"bold"),fg='#d77337',bg='white').place(x=90,y=30)
    desc=Label(Frame_login,text='Backend Details Login Page',font=("Goudy old style",15,'bold'),fg='#d25d17',bg='white').place(x=90,y=100)
        

    lbl_user=Label(Frame_login,text='User Name',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=90,y=140)
    e1=Entry(Frame_login,font=('times new roman',15))
    e1.place(x=90,y=170,width=350,height=35)

    lbl_pass=Label(Frame_login,text='Password',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=90,y=210)
    e2=Entry(Frame_login,bg='white',fg='black',font=('times new roman',15))
    e2.place(x=90,y=240,width=350,height=35)
    e2.config(show="*")

    sub_btn=Button(Frame_login,text='Submit',bg='#d77337',fg='white',relief='ridge',bd=5,font=('times new roman',15),command=Ok).place(x=80,y=290,width=180,height=40)
    exit_btn=Button(adi,text='Exit',bg='#d77337',fg='white',relief='ridge',bd=5,command=adi.destroy,font=('times new roman',15,'bold')).place(x=1100,y=550,width=100,height=40)

    adi.mainloop()
    
    

#---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
lb1=Label(root,text='Residential Society Management System',relief='ridge',bd=5,fg='black',bg='pink',
          font=('times new roman',19,'bold'),width=50,height=2).place(x=268,y=40)
        
Frame_login=Frame(root,bg='white')
Frame_login.place(x=380,y=150,height=340,width=500)

title=Label(Frame_login,text='Login Here',font=("Impact",35,"bold"),fg='#d77337',bg='white').place(x=90,y=30)
desc=Label(Frame_login,text='Residential Society Login Page',font=("Goudy old style",15,'bold'),fg='#d25d17',bg='white').place(x=90,y=100)
        

lbl_user=Label(Frame_login,text='User Name',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=90,y=140)
e1=Entry(Frame_login,font=('times new roman',15))
e1.place(x=90,y=170,width=350,height=35)

lbl_pass=Label(Frame_login,text='Password',relief='ridge',bd=5,font=("Goudy old style",15,'bold'),fg='black',bg='white').place(x=90,y=210)
e2=Entry(Frame_login,bg='white',fg='black',font=('times new roman',15))
e2.place(x=90,y=240,width=350,height=35)
e2.config(show="*")

sub_btn=Button(Frame_login,text='Submit',bg='#d77337',fg='white',relief='ridge',bd=5,font=('times new roman',15),command=Ok).place(x=80,y=290,width=180,height=40)
exit_btn=Button(root,text='Exit',bg='#d77337',fg='white',relief='ridge',bd=5,command=root.destroy,font=('times new roman',15,'bold')).place(x=1100,y=550,width=100,height=40)


root.mainloop()

#------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
